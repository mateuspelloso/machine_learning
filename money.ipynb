# %%
import pandas as pd

data = "https://raw.githubusercontent.com/mateuspelloso/machine_learning/main/data/raw/"
lifesat = pd.read_csv(url + "satisfacao.csv")

display(lifesat)
# Out:
#            Country  GDP per capita (USD)  Life satisfaction
# 0           Russia          26456.387938                5.8
# 1           Greece          27287.083401                5.4
# 2           Turkey          28384.987785                5.5
# 3           Latvia          29932.493910                5.9
# 4          Hungary          31007.768407                5.6
# 5         Portugal          32181.154537                5.4
# 6           Poland          32238.157259                6.1
# 7          Estonia          35638.421351                5.7
# 8            Spain          36215.447591                6.3
# 9         Slovenia          36547.738956                5.9
# 10       Lithuania          36732.034744                5.9
# 11          Israel          38341.307570                7.2
# 12           Italy          38992.148381                6.0
# 13  United Kingdom          41627.129269                6.8
# 14          France          42025.617373                6.5
# ...

# %%
# data = "https://github.com/mateuspelloso/machine_learning/blob/main/data/raw/satisfacao.csv"
# lifesat = pd.read_csv(data)

# %%
# Visualização de dados
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

lifesat.plot(kind='scatter', grid=True, x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

# %%
# Selecionar um modelo de regressão
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
X_new = [[37_655.2]] # PIB per capita do Chipre em 2020
print(model.predict(X_new))
# Out:
# [[6.30165767]]

# %%
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat[["Life satisfaction"]].values

lifesat.plot(kind='scatter', grid=True, x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([0, 62_500, 0, 9])

y_pred = model.predict(X_new)
plt.scatter(X_new, y_pred, color="black", s=100, marker="+", label="Chipre (predição)")
# plt.show()

X_fit = np.linspace(0, 62500, 100).reshape(-1, 1)
y_fit = model.predict(X_fit)

plt.plot(X_fit, y_fit, color="red")
